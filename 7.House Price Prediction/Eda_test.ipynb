# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test_df.shape
# Out:
# (1459, 80)

# %% [markdown]
# #### 1. Missing Value

# %%
# Printing na features
na_features = [features for features in test_df.columns if (test_df[features].isna().sum()>1)]
print(na_features)

na_features_count = {features:test_df[features].isna().sum() for features in na_features}
na_features_count = dict(sorted(na_features_count.items(), key = lambda ele: ele[1]))
na_features_count
# Out:
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
# {'Utilities': 2,
#  'BsmtFullBath': 2,
#  'BsmtHalfBath': 2,
#  'Functional': 2,
#  'MSZoning': 4,
#  'MasVnrArea': 15,
#  'MasVnrType': 16,
#  'BsmtFinType1': 42,
#  'BsmtFinType2': 42,
#  'BsmtQual': 44,
#  'BsmtExposure': 44,
#  'BsmtCond': 45,
#  'GarageType': 76,
#  'GarageYrBlt': 78,
#  'GarageFinish': 78,
#  'GarageQual': 78,
#  'GarageCond': 78,
#  'LotFrontage': 227,
#  'FireplaceQu': 730,
#  'Fence': 1169,
#  'Alley': 1352,
#  'MiscFeature': 1408,
#  'PoolQC': 1456}

# %% [markdown]
# # 2. Numerical variable

# %%
df = test_df.copy()
numerical_features = df.select_dtypes(exclude='O').columns 
print('Number of numerical features: ',len(numerical_features))
numerical_features
# Out:
# Number of numerical features:  37
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %% [markdown]
# ## datetime

# %%
year_feature = [features for features in test_df.columns if 'Year' in features or 'Yr' in features]
len(year_feature)
# Out:
# 4

# %% [markdown]
# ## discrete

# %%
df = test_df.copy()
discrete_features = [features for features in numerical_features if len(df[features].unique())<25 and features not in year_feature+['Id']]
len(discrete_features)
# Out:
# 16

# %% [markdown]
# ## continuous

# %%
df = test_df.copy()
continuous_features = [features for features in numerical_features if features not in discrete_features+year_feature+['Id']]
len(discrete_features)
# Out:
# 16

# %% [markdown]
# # 4. Categories

# %%
df = test_df.copy()
categorical_features = df.select_dtypes(include='O').columns
len(categorical_features)
# Out:
# 43

# %%
categorical_features = [features for features in categorical_features]
print(categorical_features)


#finding how many unique categories does a category has
categories_count = {features:len(df[features].unique()) for features in categorical_features}
categories_count = dict(sorted(categories_count.items(), key = lambda ele: ele[1]))
categories_count
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# {'Street': 2,
#  'Utilities': 2,
#  'CentralAir': 2,
#  'Alley': 3,
#  'LandSlope': 3,
#  'PavedDrive': 3,
#  'PoolQC': 3,
#  'LotShape': 4,
#  'LandContour': 4,
#  'RoofMatl': 4,
#  'ExterQual': 4,
#  'Heating': 4,
#  'Electrical': 4,
#  'GarageFinish': 4,
#  'MiscFeature': 4,
#  'LotConfig': 5,
#  'Condition2': 5,
#  'BldgType': 5,
#  'MasVnrType': 5,
#  'ExterCond': 5,
#  'BsmtQual': 5,
#  'BsmtCond': 5,
# ...

# %% [markdown]
# # Feature Engineering

# %%
df = test_df.copy()
numerical_features_with_nan = [features for features in numerical_features if df[features].isna().sum()>1 and features not in year_feature]
print(f'Number of numerical feature with nan: {len(numerical_features_with_nan)}')

df[numerical_features_with_nan]
# Out:
# Number of numerical feature with nan: 4
#       LotFrontage  MasVnrArea  BsmtFullBath  BsmtHalfBath
# 0            80.0         0.0           0.0           0.0
# 1            81.0       108.0           0.0           0.0
# 2            74.0         0.0           0.0           0.0
# 3            78.0        20.0           0.0           0.0
# 4            43.0         0.0           0.0           0.0
# ...           ...         ...           ...           ...
# 1454         21.0         0.0           0.0           0.0
# 1455         21.0         0.0           0.0           0.0
# 1456        160.0         0.0           1.0           0.0
# 1457         62.0         0.0           0.0           1.0
# 1458         74.0        94.0           0.0           0.0
#
# [1459 rows x 4 columns]

# %%
# replacing numerical feature with median

for features in numerical_features_with_nan:
    df[features].fillna(df[features].median(),inplace=True)
        
df[numerical_features_with_nan].isna().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFullBath    0
# BsmtHalfBath    0
# dtype: int64

# %%
# Continous values
for features in continuous_features:
    if 0 in df[features].unique():
        pass
    else:
        df[features] = np.log(df[features])

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0     1461          20       RH     4.382027  9.360655   Pave   NaN      Reg
# 1     1462          20       RL     4.394449  9.565704   Pave   NaN      IR1
# 2     1463          60       RL     4.304065  9.534595   Pave   NaN      IR1
# 3     1464          60       RL     4.356709  9.208138   Pave   NaN      IR1
# 4     1465         120       RL     3.761200  8.518193   Pave   NaN      IR1
# ...    ...         ...      ...          ...       ...    ...   ...      ...
# 1454  2915         160       RM     3.044522  7.568379   Pave   NaN      Reg
# 1455  2916         160       RM     3.044522  7.546446   Pave   NaN      Reg
# 1456  2917          20       RL     5.075174  9.903488   Pave   NaN      Reg
# 1457  2918          85       RL     4.127134  9.253496   Pave   NaN      Reg
# 1458  2919          60       RL     4.304065  9.172327   Pave   NaN      Reg
#
# ...

# %%
#categorical variables

categorical_features_with_nan = [features for features in categorical_features if df[features].isna().sum()>=1]
print('Number of categorical feature with nan: ',len(categorical_features_with_nan))

df[categorical_features_with_nan]
# Out:
# Number of categorical feature with nan:  22
#      MSZoning Alley Utilities Exterior1st Exterior2nd MasVnrType BsmtQual  \
# 0          RH   NaN    AllPub     VinylSd     VinylSd       None       TA
# 1          RL   NaN    AllPub     Wd Sdng     Wd Sdng    BrkFace       TA
# 2          RL   NaN    AllPub     VinylSd     VinylSd       None       Gd
# 3          RL   NaN    AllPub     VinylSd     VinylSd    BrkFace       TA
# 4          RL   NaN    AllPub     HdBoard     HdBoard       None       Gd
# ...       ...   ...       ...         ...         ...        ...      ...
# 1454       RM   NaN    AllPub     CemntBd     CmentBd       None       TA
# 1455       RM   NaN    AllPub     CemntBd     CmentBd       None       TA
# 1456       RL   NaN    AllPub     VinylSd     VinylSd       None       TA
# 1457       RL   NaN    AllPub     HdBoard     Wd Shng       None       Gd
# 1458       RL   NaN    AllPub     HdBoard     HdBoard    BrkFace       Gd
#
# ...

# %%
# filling categorical values with new label - Missing

for features in categorical_features_with_nan:
    df[features].fillna('Missing',inplace=True)
    
#checking if null values are replaced or not
df[categorical_features_with_nan].isna().sum()
# Out:
# MSZoning        0
# Alley           0
# Utilities       0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# KitchenQual     0
# Functional      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# SaleType        0
# dtype: int64

# %%
#datetime

year_features_with_nan = [features for features in year_feature if df[features].isna().sum()>1]
print('Number of year feature with nan: ',len(year_features_with_nan))

for features in year_features_with_nan:
    year_median = df[features].median()
    df[features].fillna(year_median,inplace=True)
    
df[year_features_with_nan].isna().sum()
# Out:
# Number of year feature with nan:  1
# GarageYrBlt    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
#rare categorical feature

for features in categorical_features:
    temp = df.groupby(features).count()/len(df)
    temp_df = temp[temp>0.01].index
    df[features] = np.where(df[features].isin(temp_df),df[features],'rare_cat')

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley  \
# 0     1461          20       RH     4.382027  9.360655   Pave  Missing
# 1     1462          20       RL     4.394449  9.565704   Pave  Missing
# 2     1463          60       RL     4.304065  9.534595   Pave  Missing
# 3     1464          60       RL     4.356709  9.208138   Pave  Missing
# 4     1465         120       RL     3.761200  8.518193   Pave  Missing
# ...    ...         ...      ...          ...       ...    ...      ...
# 1454  2915         160       RM     3.044522  7.568379   Pave  Missing
# 1455  2916         160       RM     3.044522  7.546446   Pave  Missing
# 1456  2917          20       RL     5.075174  9.903488   Pave  Missing
# 1457  2918          85       RL     4.127134  9.253496   Pave  Missing
# 1458  2919          60       RL     4.304065  9.172327   Pave  Missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
categorical_features_with_nan
# Out:
# ['MSZoning',
#  'Alley',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType']
